# %%
import pandas as pd
import numpy as np

from scipy.stats import ttest_ind
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\Rutvi\OneDrive\Desktop\Streaming Churn Intelligence Behavioral Segmentation & Retention Analytics\archive (6)\netflix_large_user_data.xlsx")

df.head()
# Out:
#   Customer ID  Subscription Length (Months)  \
# 0      C00001                            12
# 1      C00002                            12
# 2      C00003                             3
# 3      C00004                             3
# 4      C00005                            24
#
#    Customer Satisfaction Score (1-10)  Daily Watch Time (Hours)  \
# 0                                  10                      4.85
# 1                                   8                      1.75
# 2                                   4                      2.75
# 3                                   7                      3.00
# 4                                   2                      1.37
#
#    Engagement Rate (1-10) Device Used Most Often Genre Preference  \
# 0                       4                 Tablet           Action
# 1                       9                 Laptop         Thriller
# 2                       9               Smart TV           Comedy
# ...

# %%
df['churn_flag'] = df['Churn Status (Yes/No)'].map({'Yes': 1, 'No': 0})

# %%
df['group'] = df['Engagement Rate (1-10)'].apply(
    lambda x: 'A' if x < 6 else 'B'
)

df['group'].value_counts()
# Out:
# group
# B    509
# A    491
# Name: count, dtype: int64

# %%
df['group'] = df['Engagement Rate (1-10)'].apply(
    lambda x: 'A' if x < 6 else 'B'
)

df['group'].value_counts()
# Out:
# group
# B    509
# A    491
# Name: count, dtype: int64

# %%
sns.barplot(x='group', y='churn_flag', data=df)
plt.title("Churn Rate by A/B Groups")
plt.show()

# %% [markdown]
# # 📌 Final Conclusion — Notebook 08
#
# ## 🧠 What We Did
# We performed A/B testing to compare churn behavior between two engagement-based groups.
#
# ---
#
# ## 📊 Outcome
# - Statistical test evaluates difference in churn rates
# - Helps validate engagement strategies
#
# ---
#
# ## 💡 Business Insight
# A/B testing is essential for:
# - Product validation
# - Feature impact analysis
# - Data-driven decision-making
#
# ---
